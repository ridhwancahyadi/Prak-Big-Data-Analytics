# %% [markdown]
# ## Prak Big Data Analytics
# ### Pertemuan 3

# %%
# Import library yang diperlukan
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn
import seaborn as sns

# %% [markdown]
# ### 1. Menggunakan fungsi Membuat Ploting data pada sumbu ordinat

# %% [markdown]
# a. Membuat garis ordinat untuk ploting data menggunakan perintah dibawah ini:

# %%
plt.axis([0,10,0,25])
# Out:
# (0.0, 10.0, 0.0, 25.0)

# %% [markdown]
# b. Menampilkan data ordinat untuk data {(2,4), (2.5,11), (6,14), (7,17), (9,24)} gunakan
# perintah dibawah ini

# %%
plt.plot([2,2.5,6,7,9], [4,11,14,17,2], 'gs')

# %% [markdown]
# c. Membuat garis pada titik-titik ordinat diatas dengan menghilangkan “gs” dan
# tampilan dibawah ini

# %%
plt.plot([2,2.5,6,7,9], [4,11,14,17,24])
plt.show()

# %% [markdown]
# d. Membuat ploting data dengan memberi nama variabel sumbu x dan sumbu y, seperti
# dibawah ini

# %% [markdown]
# #### Manajemen data file csv

# %% [markdown]
# a. Menampilkan data → Buatlah data seperti dibawah ini dan simpan dengan nama
# data3.csv

# %%
plt.plot([2,3,4,5], [3,8,10,12])
plt.xlabel('Actual brith weight')
plt.ylabel('Estimated birth weight')
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# memanggil dataset
dataset = pd.read_csv('/content/drive/MyDrive/Prak Big Data Analytics/Per-3/data3.csv')

# %%
dataset.keys()
# Out:
# Index(['Nilai UTS', 'Nilai UAS'], dtype='object')

# %%
dataset.shape
# Out:
# (12, 2)

# %%
pd.plotting.register_matplotlib_converters()
# %matplotlib inline

# %%
insurance = '/content/drive/MyDrive/Prak Big Data Analytics/Per-3/insurance.csv'
insurance_data = pd.read_csv(insurance)
insurance_data.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['expenses'])
# Out:
# <Axes: xlabel='bmi', ylabel='expenses'>

# %%
sns.regplot(x=insurance_data['bmi'], y=insurance_data['expenses'])
# Out:
# <Axes: xlabel='bmi', ylabel='expenses'>

# %%
sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['expenses'],
                hue= insurance_data['smoker'])
# Out:
# <Axes: xlabel='bmi', ylabel='expenses'>

# %%
sns.lmplot(x='bmi',y='expenses', hue='smoker', data=insurance_data)

# %% [markdown]
# ### Latihan 2
# Contoh penggunaan fungsi yang dimiliki library Pandas untuk menampilkan data (minimal 8 fungsi)

# %% [markdown]
# #### info()

# %%
insurance_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   expenses  1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# info(): Menampilkan informasi keseluruhan DataFrame termasuk tipe data dan nilai yang tidak null.

# %% [markdown]
# #### describe()

# %%
insurance_data.describe(include='all')
# Out:
#                 age   sex          bmi     children smoker     region  \
# count   1338.000000  1338  1338.000000  1338.000000   1338       1338
# unique          NaN     2          NaN          NaN      2          4
# top             NaN  male          NaN          NaN     no  southeast
# freq            NaN   676          NaN          NaN   1064        364
# mean      39.207025   NaN    30.665471     1.094918    NaN        NaN
# std       14.049960   NaN     6.098382     1.205493    NaN        NaN
# min       18.000000   NaN    16.000000     0.000000    NaN        NaN
# 25%       27.000000   NaN    26.300000     0.000000    NaN        NaN
# 50%       39.000000   NaN    30.400000     1.000000    NaN        NaN
# 75%       51.000000   NaN    34.700000     2.000000    NaN        NaN
# max       64.000000   NaN    53.100000     5.000000    NaN        NaN
#
#             expenses
# count    1338.000000
# unique           NaN
# top              NaN
# freq             NaN
# ...

# %% [markdown]
# describe(): Menampilkan ringkasan statistik dari DataFrame seperti mean, median, min, max, dsb.

# %% [markdown]
# #### isnull()

# %%
insurance_data.isnull()
# Out:
#         age    sex    bmi  children  smoker  region  expenses
# 0     False  False  False     False   False   False     False
# 1     False  False  False     False   False   False     False
# 2     False  False  False     False   False   False     False
# 3     False  False  False     False   False   False     False
# 4     False  False  False     False   False   False     False
# ...     ...    ...    ...       ...     ...     ...       ...
# 1333  False  False  False     False   False   False     False
# 1334  False  False  False     False   False   False     False
# 1335  False  False  False     False   False   False     False
# 1336  False  False  False     False   False   False     False
# 1337  False  False  False     False   False   False     False
#
# [1338 rows x 7 columns]

# %% [markdown]
# isnull(): Mengidentifikasi nilai yang hilang (NaN) dalam DataFrame.

# %%
insurance_data.select_dtypes(include='object')
# Out:
#          sex smoker     region
# 0     female    yes  southwest
# 1       male     no  southeast
# 2       male     no  southeast
# 3       male     no  northwest
# 4       male     no  northwest
# ...      ...    ...        ...
# 1333    male     no  northwest
# 1334  female     no  northeast
# 1335  female     no  southeast
# 1336  female     no  southwest
# 1337  female    yes  northwest
#
# [1338 rows x 3 columns]

# %%
query = insurance_data.query("sex == 'female' and age > 30 and smoker == 'yes'")
query.shape
# Out:
# (75, 7)

# %%
insurance_data.query("sex == 'female' and age > 30 and smoker == 'yes'")
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 11     62  female  26.3         0    yes  southeast  27808.73
# 23     34  female  31.9         1    yes  northeast  37701.88
# 58     53  female  22.9         1    yes  southeast  23244.79
# 84     37  female  34.8         2    yes  southwest  39836.52
# 86     57  female  31.2         0    yes  northwest  43578.94
# ...   ...     ...   ...       ...    ...        ...       ...
# 1208   37  female  25.6         1    yes  northeast  20296.86
# 1218   46  female  34.6         1    yes  southwest  41661.60
# 1281   47  female  27.6         2    yes  northwest  24535.70
# 1323   42  female  40.4         2    yes  southeast  43896.38
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [75 rows x 7 columns]

# %%
byregion = insurance_data.groupby(by='region')
byregion.count()
# Out:
#            age  sex  bmi  children  smoker  expenses
# region
# northeast  324  324  324       324     324       324
# northwest  325  325  325       325     325       325
# southeast  364  364  364       364     364       364
# southwest  325  325  325       325     325       325

# %%
insurance_data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1333    False
# 1334    False
# 1335    False
# 1336    False
# 1337    False
# Length: 1338, dtype: bool

# %%
rename_to_gender = insurance_data.rename(columns={'sex': 'gender'})
rename_to_gender.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   gender    1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   expenses  1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
insurance_data.size
# Out:
# 9366

# %%
insurance_data.iloc[0]
# Out:
# age                19
# sex            female
# bmi              27.9
# children            0
# smoker            yes
# region      southwest
# expenses     16884.92
# Name: 0, dtype: object

# %%
insurance_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   expenses  1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# #### Tugas tentang Seaborn

# %%
# histplot
sns.histplot(data=insurance_data, x='bmi', kde=True, bins=20)
# Out:
# <Axes: xlabel='bmi', ylabel='Count'>

# %%
# barplot
sns.barplot(data=insurance_data, x='expenses', y='region', hue='region', palette='dark:blue')
# Out:
# <Axes: xlabel='expenses', ylabel='region'>
