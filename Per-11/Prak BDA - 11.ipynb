# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm, datasets

# %%
iris = datasets.load_iris()

# %%
X = iris.data[:, :2]
y = iris.target
h = .02
C = 1.0

# %%
svc = svm.SVC(kernel='linear', C=C).fit(X,y)

# %%
rbf_svc = svm.SVC(kernel='rbf', gamma=0.7, C=C).fit(X,y)

# %%
poly_svc = svm.SVC(kernel='poly', degree=3, C=C).fit(X,y)

# %%
lin_svc = svm.LinearSVC(C=C).fit(X,y)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %%
X_min, X_max = X[:, 0].min() - 1, X[:, 0].max() + 1

# %%
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1

# %%
xx, yy = np.meshgrid(np.arange(X_min, X_max, h),
                   np.arange(y_min, y_max, h))

# %%
titles = ['SVC with Linear Kernel',
          'Linear SVC (Linear Kernel)',
          'SVC with RBF Kernel',
          'SVC with Poluominal (degree 3) Kernel']

# %%
for i, clf in enumerate((svc, lin_svc, rbf_svc, poly_svc)):
  plt.subplot(2,2, i+1)
  plt.subplots_adjust(wspace=0.4, hspace=0.4)

  Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

  Z = Z.reshape(xx.shape)
  plt.contourf(xx, yy, Z, cmap=plt.cm.coolwarm, alpha=0.8)

  plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.coolwarm)
  plt.xlabel('Sepal Length')
  plt.ylabel('Sepal Width')
  plt.xlim(xx.min(), xx.max())
  plt.ylim(yy.min(), yy.max())
  plt.xticks(())
  plt.yticks(())
  plt.title(titles[i])

plt.show()

# %% [markdown]
# ## Latihan
# 1. Lakukan plotting terhadap 2 variabel Petallength dan Petal Width dengan sumbu
# X Petalwidth dan sumbu Y Petallength

# %%
X_petal = iris.data[:, 2:4]
y = iris.target
h = .02
C = 1.0

# %%
X_petal[:5]
# Out:
# array([[1.4, 0.2],
#        [1.4, 0.2],
#        [1.3, 0.2],
#        [1.5, 0.2],
#        [1.4, 0.2]])

# %%
svc_petal = svm.SVC(kernel='linear', C=C).fit(X_petal,y)

# %%
rbf_svc_petal = svm.SVC(kernel='rbf', gamma=0.7, C=C).fit(X_petal,y)

# %%
poly_svc_petal = svm.SVC(kernel='poly', degree=3, C=C).fit(X_petal,y)

# %%
lin_svc_petal = svm.LinearSVC(C=C).fit(X_petal,y)

# %%
X_min_petal, X_max_petal = X_petal[:, 0].min() - 1, X_petal[:, 0].max() + 1

# %%
y_min_petal, y_max_petal = X_petal[:, 1].min() - 1, X_petal[:, 1].max() + 1

# %%
xx_petal, yy_petal = np.meshgrid(np.arange(X_min_petal, X_max_petal, h),
                   np.arange(y_min_petal, y_max_petal, h))

# %%
for i, clf in enumerate((svc_petal, lin_svc_petal, rbf_svc_petal, poly_svc_petal)):
  plt.subplot(2,2, i+1)
  plt.subplots_adjust(wspace=0.4, hspace=0.4)

  Z_petal = clf.predict(np.c_[xx_petal.ravel(), yy_petal.ravel()])

  Z_petal = Z_petal.reshape(xx_petal.shape)
  plt.contourf(xx_petal, yy_petal, Z_petal, cmap=plt.cm.coolwarm, alpha=0.8)

  plt.scatter(X_petal[:, 0], X_petal[:, 1], c=y, cmap=plt.cm.coolwarm)
  plt.xlabel('Petal Length')
  plt.ylabel('Petal Width')
  plt.xlim(xx_petal.min(), xx_petal.max())
  plt.ylim(yy_petal.min(), yy_petal.max())
  plt.xticks(())
  plt.yticks(())
  plt.title(titles[i])

plt.show()
