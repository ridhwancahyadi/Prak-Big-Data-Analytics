# %%
import pandas as pd

# %%
data1 = '/content/drive/MyDrive/Prak Big Data Analytics/Per-5/pegawai_cab01.csv'

# %%
df_pegawai = pd.read_csv(data1)
df_pegawai
# Out:
#      nik             nama     gaji    tglmasuk      job_id  \
# 0    206    William Gietz   8300.0  1990-10-01  AC_ACCOUNT
# 1    205  Shelley Higgins  12000.0  1987-09-30      AC_MGR
# 2    200  Jennifer Whalen   4400.0  1987-09-25     AD_ASST
# 3    100      Steven King  24000.0  1983-06-17     AD_PRES
# 4    101    Neena Kochhar  17000.0  1987-06-18       AD_VP
# ..   ...              ...      ...         ...         ...
# 102  120    Matthew Weiss   8000.0  1984-07-07      ST_MAN
# 103  121       Adam Fripp   8200.0  1984-07-08      ST_MAN
# 104  122   Payam Kaufling   7900.0  1987-07-09      ST_MAN
# 105  123   Shanta Vollman   6500.0  1987-07-10      ST_MAN
# 106  124    Kevin Mourgos   5800.0  1987-07-11      ST_MAN
#
#                          job_title
# 0                Public Accountant
# 1               Accounting Manager
# 2         Administration Assistant
# 3                        President
# 4    Administration Vice President
# ..                             ...
# ...

# %%
df_pegawai.isnull()
# Out:
#        nik   nama   gaji  tglmasuk  job_id  job_title
# 0    False  False  False     False   False      False
# 1    False  False  False     False   False      False
# 2    False  False  False     False   False      False
# 3    False  False  False     False   False      False
# 4    False  False  False     False   False      False
# ..     ...    ...    ...       ...     ...        ...
# 102  False  False  False     False   False      False
# 103  False  False  False     False   False      False
# 104  False  False  False     False   False      False
# 105  False  False  False     False   False      False
# 106  False  False  False     False   False      False
#
# [107 rows x 6 columns]

# %%
df_pegawai.isnull().sum()
# Out:
# nik          0
# nama         0
# gaji         0
# tglmasuk     0
# job_id       0
# job_title    0
# dtype: int64

# %%
df_pegawai['job_title'].unique()
# Out:
# array(['Public Accountant', 'Accounting Manager',
#        'Administration Assistant', 'President',
#        'Administration Vice President', 'Accountant', 'Finance Manager',
#        'Human Resources Representative', 'Programmer', 'IT SUPPORT',
#        'Marketing Manager', 'Marketing Representative',
#        'Public Relations Representative', 'Purchasing Clerk',
#        'Purchasing Manager', 'Sales Manager', 'Sales Representative',
#        'Shipping Clerk', 'Stock Clerk', 'Stock Manager'], dtype=object)

# %%
df_pegawai[df_pegawai['job_title'] == 'Programmer']['gaji'].mean()
# Out:
# 5120.0

# %%
df_pegawai['gaji'].median()
# Out:
# 6100.0

# %%
df_pegawai[df_pegawai['job_title'] == 'Programmer']['gaji'].median()
# Out:
# 4800.0

# %%
df_pegawai['gaji'].std()
# Out:
# 3929.0522964844795

# %%
def stdev(nums):
  diffs = 0
  avg = sum(nums)/len(nums)
  for n in nums:
      diffs += (n - avg)**(2)
  return (diffs/(len(nums)-1))**(0.5)

# %%
gaji_std = df_pegawai['gaji']
print(stdev(gaji_std))
# Out:
# 3929.0522964844795
